# %%
# %cd /content/drive/MyDrive/Yolov8_two
# Out:
# /content/drive/MyDrive/Yolov8_two

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.2/984.2 kB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/yolov8new/data.yaml epochs=150 imgsz=640 batch=64
# Out:
# Ultralytics 8.3.117 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolov8new/runs/detect/train3/weights/best.pt conf=0.25 source=/content/drive/MyDrive/yolov8new/new_dataset/test/images
# Out:
# Ultralytics 8.3.117 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/71 /content/drive/MyDrive/yolov8new/new_dataset/test/images/GOPR0492_MP4-100_jpg.rf.b8becff32c2326c70edb8d719f0239cb.jpg: 640x640 1 drowsy, 16.3ms
# image 2/71 /content/drive/MyDrive/yolov8new/new_dataset/test/images/GOPR0492_MP4-109_jpg.rf.d5dc228e2758dbf1905b1885faedcb88.jpg: 640x640 1 awake, 16.3ms
# image 3/71 /content/drive/MyDrive/yolov8new/new_dataset/test/images/GOPR0492_MP4-117_jpg.rf.0db739d10912e81f52f6c7f2454b1276.jpg: 640x640 1 drowsy, 16.3ms
# image 4/71 /content/drive/MyDrive/yolov8new/new_dataset/test/images/GOPR0492_MP4-121_jpg.rf.cab81895fd844e5a742213209ce53a29.jpg: 640x640 1 awake, 16.3ms
# image 5/71 /content/drive/MyDrive/yolov8new/new_dataset/test/images/GOPR0492_MP4-126_jpg.rf.f31e7d36af507bb7f9b2980de25378ec.jpg: 640x640 1 awake, 16.3ms
# ...
